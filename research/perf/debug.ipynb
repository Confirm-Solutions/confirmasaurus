# %%
# runtime duckdb = 3.8978
# runtime clickhouse = 37.15
# runtime ch + modal = 57.5

# %%
from imprint.nb_util import setup_nb
setup_nb()
from confirm.adagrid.debug import get_logs

#modal + ch
# logs, log_df, db = get_logs('44dcf9061f5f4bcd81d85255f35cdedc')
# just ch
# logs, log_df, db = get_logs('a73de730d75a4b248974dac8bd7aeba2')

# big ch
logs, log_df, db = get_logs('791ead8ad7ae463e8a98d730966ec15b')
# Out:
# [worker_id=None] 2023-03-03 17:46:00,821 - confirm.cloud.clickhouse - INFO
# Clickhouse config: default@t2n4z83v82.us-east-1.aws.clickhouse.cloud:8443/None
# [worker_id=None] 2023-03-03 17:46:01,069 - confirm.cloud.clickhouse - INFO
# Connected to job 791ead8ad7ae463e8a98d730966ec15b

# %%
log_df[(log_df['name'] == 'confirm.adagrid.step') & (log_df['message'].str.contains('packet insertion'))]
# Out:
#      worker_id                                t                  name  \
# 12           1 2023-03-03 17:41:37.674219+00:00  confirm.adagrid.step
# 35           1 2023-03-03 17:41:39.498073+00:00  confirm.adagrid.step
# 56           1 2023-03-03 17:41:41.324041+00:00  confirm.adagrid.step
# 82           1 2023-03-03 17:41:43.901104+00:00  confirm.adagrid.step
# 108          1 2023-03-03 17:41:46.405360+00:00  confirm.adagrid.step
# 134          1 2023-03-03 17:41:48.904915+00:00  confirm.adagrid.step
# 182          1 2023-03-03 17:41:52.254161+00:00  confirm.adagrid.step
# 255          1 2023-03-03 17:41:56.441558+00:00  confirm.adagrid.step
# 300          1 2023-03-03 17:42:01.011581+00:00  confirm.adagrid.step
# 407          1 2023-03-03 17:42:09.194575+00:00  confirm.adagrid.step
# 500          1 2023-03-03 17:42:17.956670+00:00  confirm.adagrid.step
# 569          1 2023-03-03 17:42:25.892433+00:00  confirm.adagrid.step
# 913          1 2023-03-03 17:43:11.886971+00:00  confirm.adagrid.step
#
#                                               pathname  lineno  levelno  \
# 12   /Users/tbent/confirm/confirmasaurus/confirm/ad...      26       10
# 35   /Users/tbent/confirm/confirmasaurus/confirm/ad...      26       10
# 56   /Users/tbent/confirm/confirmasaurus/confirm/ad...      26       10
# 82   /Users/tbent/confirm/confirmasaurus/confirm/ad...      26       10
# 108  /Users/tbent/confirm/confirmasaurus/confirm/ad...      26       10
# 134  /Users/tbent/confirm/confirmasaurus/confirm/ad...      26       10
# 182  /Users/tbent/confirm/confirmasaurus/confirm/ad...      26       10
# 255  /Users/tbent/confirm/confirmasaurus/confirm/ad...      26       10
# 300  /Users/tbent/confirm/confirmasaurus/confirm/ad...      26       10
# 407  /Users/tbent/confirm/confirmasaurus/confirm/ad...      26       10
# 500  /Users/tbent/confirm/confirmasaurus/confirm/ad...      26       10
# 569  /Users/tbent/confirm/confirmasaurus/confirm/ad...      26       10
# 913  /Users/tbent/confirm/confirmasaurus/confirm/ad...      26       10
#
#     levelname                                            message  \
# 12      DEBUG  waiting for packet insertion took 0.9128069877...
# 35      DEBUG  waiting for packet insertion took 0.6679491996...
# 56      DEBUG  waiting for packet insertion took 0.6503129005...
# 82      DEBUG  waiting for packet insertion took 0.8429880142...
# 108     DEBUG  waiting for packet insertion took 0.6294999122...
# 134     DEBUG  waiting for packet insertion took 0.7715599536...
# 182     DEBUG  waiting for packet insertion took 1.0095260143...
# 255     DEBUG  waiting for packet insertion took 1.2343459129...
# 300     DEBUG  waiting for packet insertion took 0.9319469928...
# 407     DEBUG  waiting for packet insertion took 1.9217658042...
# 500     DEBUG  waiting for packet insertion took 1.1720530986...
# 569     DEBUG  waiting for packet insertion took 1.4136750698...
# 913     DEBUG  waiting for packet insertion took 5.7684650421...
#
#                           t_str
# 12   2023-03-03 17:41:37.674219
# 35   2023-03-03 17:41:39.498073
# 56   2023-03-03 17:41:41.324041
# 82   2023-03-03 17:41:43.901104
# 108  2023-03-03 17:41:46.405360
# 134  2023-03-03 17:41:48.904915
# 182  2023-03-03 17:41:52.254161
# 255  2023-03-03 17:41:56.441558
# 300  2023-03-03 17:42:01.011581
# 407  2023-03-03 17:42:09.194575
# 500  2023-03-03 17:42:17.956670
# 569  2023-03-03 17:42:25.892433
# 913  2023-03-03 17:43:11.886971

# %%
backend_times = log_df[(log_df['name'] == 'confirm.adagrid.backend') & (log_df['message'].str.contains('took'))]['message']

split = backend_times.str.split('took')
split.str[1].astype(float).sum()
# Out:
# 194.1829112815857

# %%
backend_times
# Out:
# 5                           init took 2.6582419872283936
# 6                       setup took 2.002716064453125e-05
# 13     process_initial_incompletes took 1.76260495185...
# 135                        _run_zone(0, 1, 6) took 11.23
# 136                    run_zones took 11.231770277023315
# 501                       _run_zone(0, 6, 11) took 29.05
# 502                     run_zones took 29.05069899559021
# 917                      _run_zone(0, 11, 16) took 54.60
# 918                     run_zones took 54.59957504272461
# Name: message, dtype: object

# %%
rpt_df = db.get_reports()

# %%
rpt_df[['worker_id', 'zone_id', 'step_id', 'n_tiles', 'status', 'runtime_total', 'runtime_process_tiles']]
# Out:
#     worker_id  zone_id  step_id  n_tiles    status  runtime_total  \
# 6           1        0        0        6   WORKING       0.847564
# 8           1        0        1       40   WORKING       0.235390
# 7           1        0        1        6  NEW_STEP       0.912803
# 10          1        0        2      288   WORKING       0.130664
# 9           1        0        2       40  NEW_STEP       1.039606
# 13          1        0        3     1024   WORKING       0.325842
# 12          1        0        3       72   WORKING       0.167512
# 11          1        0        3      288  NEW_STEP       1.403058
# 15          1        0        4     1024   WORKING       0.276500
# 16          1        0        4      840   WORKING       0.413105
# 14          1        0        4     1072  NEW_STEP       1.458769
# 19          1        0        5     1024   WORKING       0.302074
# 18          1        0        5      816   WORKING       0.184280
# 17          1        0        5     1840  NEW_STEP       1.423001
# 22          1        0        6     1024   WORKING       0.797355
# 25          1        0        6     1024   WORKING       0.926796
# 23          1        0        6     1024   WORKING       0.793679
# 21          1        0        6     1024   WORKING       0.398379
# 24          1        0        6      912   WORKING       0.792441
# 20          1        0        6     1600  NEW_STEP       1.405739
# 29          1        0        7     1024   WORKING       0.868575
# 31          1        0        7     1024   WORKING       0.866371
# 27          1        0        7     1024   WORKING       0.257831
# 28          1        0        7     1024   WORKING       0.400345
# 30          1        0        7     1024   WORKING       0.865873
# 33          1        0        7     1024   WORKING       1.550140
# 36          1        0        7     1024   WORKING       1.551427
# 35          1        0        7     1024   WORKING       1.553252
# 34          1        0        7     1024   WORKING       1.550317
# 32          1        0        7      960   WORKING       1.550145
# 26          1        0        7     4704  NEW_STEP       1.391355
# 38          1        0        8     1024   WORKING       0.440081
# 39          1        0        8     1024   WORKING       1.301094
# 42          1        0        8     1024   WORKING       1.302066
# 40          1        0        8     1024   WORKING       1.301861
# 41          1        0        8      704   WORKING       1.302571
# 37          1        0        8     4800  NEW_STEP       2.329597
# 44          1        0        9     1024   WORKING       0.761515
# 45          1        0        9     1024   WORKING       0.996635
# 46          1        0        9     1024   WORKING       3.151420
# 48          1        0        9     1024   WORKING       3.151192
# 53          1        0        9     1024   WORKING       3.153138
# 57          1        0        9     1024   WORKING       4.113323
# 54          1        0        9     1024   WORKING       3.151954
# 56          1        0        9     1024   WORKING       4.112916
# 59          1        0        9     1024   WORKING       4.114006
# 58          1        0        9     1024   WORKING       4.113814
# 55          1        0        9     1024   WORKING       3.151916
# 47          1        0        9     1024   WORKING       3.151185
# 49          1        0        9     1024   WORKING       3.151275
# 52          1        0        9     1024   WORKING       3.151183
# 50          1        0        9     1024   WORKING       3.151255
# 51          1        0        9      640   WORKING       3.150994
# 43          1        0        9     2016  NEW_STEP       2.141706
# 61          1        0       10     1024   WORKING       0.623777
# 63          1        0       10     1024   WORKING       3.156475
# 62          1        0       10     1024   WORKING       3.155572
# 66          1        0       10     1024   WORKING       3.160386
# 65          1        0       10     1024   WORKING       3.159431
# 72          1        0       10     1024   WORKING       4.131502
# 68          1        0       10     1024   WORKING       3.160582
# 70          1        0       10     1024   WORKING       3.160398
# 67          1        0       10     1024   WORKING       3.159962
# 71          1        0       10     1024   WORKING       4.130780
# 69          1        0       10     1024   WORKING       3.160143
# 64          1        0       10      832   WORKING       3.156322
# 60          1        0       10    12096  NEW_STEP       3.456086
# 74          1        0       11     1024   WORKING       0.770191
# 80          1        0       11     1024   WORKING       4.555493
# 76          1        0       11     1024   WORKING       4.549716
# 75          1        0       11     1024   WORKING       4.551781
# 81          1        0       11     1024   WORKING       4.549951
# 78          1        0       11     1024   WORKING       4.550042
# 79          1        0       11     1024   WORKING       4.556492
# 77          1        0       11      960   WORKING       4.549710
# 73          1        0       11     8128  NEW_STEP       1.960341
# 88          1        0       12     1024   WORKING      38.171661
# 84          1        0       12     1024   WORKING      38.170376
# 83          1        0       12     1024   WORKING       0.957101
# 89          1        0       12     1024   WORKING      38.171369
# 94          1        0       12     1024   WORKING      38.186856
# 87          1        0       12     1024   WORKING      38.170784
# 85          1        0       12     1024   WORKING      38.170600
# 90          1        0       12     1024   WORKING      38.171442
# 86          1        0       12     1024   WORKING      38.171182
# 91          1        0       12     1024   WORKING      38.171509
# 95          1        0       12     1024   WORKING      38.186075
# 4           1        0       12     1024   WORKING      38.171687
# 0           1        0       12     1024   WORKING      38.171539
# 3           1        0       12     1024   WORKING      38.172001
# 2           1        0       12     1024   WORKING      38.169907
# 1           1        0       12     1024   WORKING      38.169706
# 92          1        0       12     1024   WORKING      38.174310
# 5           1        0       12     1024   WORKING      38.169845
# 93          1        0       12     1024   WORKING      38.184863
# 96          1        0       12     1024   WORKING      38.185018
# 97          1        0       12     1024   WORKING      38.186003
# 98          1        0       12     1024   WORKING      38.186119
# 99          1        0       12     1024   WORKING      38.186172
# 82          1        0       12     8128  NEW_STEP       2.019862
#
#     runtime_process_tiles
# 6                0.800384
# 8                0.050884
# 7                     NaN
# 10               0.077435
# 9                     NaN
# 13               0.151567
# 12               0.069526
# 11                    NaN
# 15               0.167619
# 16               0.135384
# 14                    NaN
# 19               0.116020
# 18               0.095635
# 17                    NaN
# 22               0.118051
# 25               0.126954
# 23               0.119039
# 21               0.217558
# 24               0.155354
# 20                    NaN
# 29               0.131794
# 31               0.147149
# 27               0.142278
# 28               0.137296
# 30               0.184052
# 33               0.143508
# 36               0.130484
# 35               0.128578
# 34               0.135827
# 32               0.141873
# 26                    NaN
# 38               0.294169
# 39               0.206739
# 42               0.228747
# 40               0.243607
# 41               0.180306
# 37                    NaN
# 44               0.587962
# 45               0.234828
# 46               0.216083
# 48               0.222583
# 53               0.223983
# 57               0.219417
# 54               0.217286
# 56               0.312906
# 59               0.208942
# 58               0.217541
# 55               0.220794
# 47               0.221713
# 49               0.230754
# 52               0.223698
# 50               0.221417
# 51               0.154320
# 43                    NaN
# 61               0.448517
# 63               0.294674
# 62               0.295959
# 66               0.286844
# 65               0.273892
# 72               0.299593
# 68               0.277018
# 70               0.289015
# 67               0.280000
# 71               0.668448
# 69               0.286153
# 64               0.246776
# 60                    NaN
# 74               0.622384
# 80               0.543080
# 76               0.544646
# 75               0.542668
# 81               0.542631
# 78               0.544410
# 79               0.556827
# 77               0.503558
# 73                    NaN
# 88               0.559908
# 84               0.581767
# 83               0.822880
# 89               0.588541
# 94               0.632085
# 87               0.581246
# 85               0.625203
# 90               0.605074
# 86               0.677143
# 91               0.601814
# 95               0.622479
# 4                0.576423
# 0                0.595427
# 3                0.570751
# 2                0.626981
# 1                0.566774
# 92               0.573096
# 5                0.575195
# 93               0.583928
# 96               0.607680
# 97               0.573533
# 98               0.683505
# 99               0.596919
# 82                    NaN

# %%
rpt_df['runtime_total'].sum()
# Out:
# 1004.698005437851

# %%
rpt_df['runtime_process_tiles'].sum()
# Out:
# 31.28748655319214

# %%
rpt_df.query('status == "WORKING" and step_id == 12')['runtime_process_tiles'].sum()
# Out:
# 14.02835202217102
