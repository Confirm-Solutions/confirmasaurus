# %%
import time

start = time.time()
import numpy as np  # noqa: E402
import imprint as ip  # noqa: E402
ip.setup_nb()

from imprint.models.ztest import ZTest1D  # noqa: E402
import confirm.adagrid as ada  # noqa: E402
from confirm.cloud.modal_backend import ModalBackend  # noqa: E402
import confirm.models.wd41 as wd41

import dotenv

dotenv.load_dotenv()
# d = 3
# g = ip.cartesian_grid(
#     theta_min=np.full(d, -1),
#     theta_max=np.full(d, 0),
#     null_hypos=[ip.hypo("theta0 > theta1")],
# )
model = wd41.WD41(0, 1, ignore_intersection=True)
g = ip.cartesian_grid(
    [-2.5, -2.5, -2.5, -2.5],
    [1.0, 1.0, 1.0, 1.0],
    n=[10, 10, 10, 10],
    null_hypos=model.null_hypos,
)
db = ada.ada_validate(
    wd41.WD41,
    model_kwargs={"ignore_intersection": True},
    g=g,
    lam=-1.96,
    prod=False,
    n_K_double=7,
    max_target=0.001,
    global_target=0.002,
    step_size=2**17,
    packet_size=2**13,
    n_steps=6,
    n_zones=4,
    coordinate_every=2,
    # backend=CoiledBackend()
    backend=ModalBackend(n_workers=1, gpu="any"),
)
# Out:
# 2023-03-17 16:19:56,814 - imprint - DEBUG
# Enabling 64-bit floats in JAX.
# 2023-03-17 16:19:57,236 - imprint.grid - DEBUG
# _gen_short_uuids(n=10000, worker_id=1, t=1679084397, n_bits=18, worker_bits=18) = [4705336715165040640 4705336715165040641 4705336715165040642, ...]:
# 2023-03-17 16:19:57,240 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:19:57,244 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:19:57,276 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:19:57,308 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:19:57,324 - imprint.grid - DEBUG
# _gen_short_uuids(n=2000, worker_id=1, t=1679084398, n_bits=18, worker_bits=18) = [4705336783884517376 4705336783884517377 4705336783884517378, ...]:
# 2023-03-17 16:19:57,794 - imprint.grid - DEBUG
# _gen_short_uuids(n=5584, worker_id=1, t=1679084399, n_bits=18, worker_bits=18) = [4705336852603994112 4705336852603994113 4705336852603994114, ...]:
# 2023-03-17 16:19:57,898 - confirm.adagrid.init - DEBUG
# Initialized database with 9053 tiles and 2 null hypos. The tiles are split between 4 zones with packet_size=8192.
# 2023-03-17 16:19:57,902 - confirm.adagrid.init - INFO
# Config (minus system info):
# {'lam': -1.96, 'model_seed': 0, 'delta': 0.01, 'init_K': 8192, 'n_K_double': 7, 'tile_batch_size': 64, 'max_target': 0.001, 'global_target': 0.002, 'n_steps': 6, 'step_size': 131072, 'timeout': 43200, 'packet_size': 8192, 'coordinate_every': 2, 'n_zones': 4, 'prod': False, 'job_name': None, 'n_workers': 1, 'gpu': 'any', 'model_name': 'WD41', 'model_kwargs_json': '{"ignore_intersection": true}', 'worker_id': 1, 'jax_platform': 'cpu', 'git_hash': '0626373cfb1c5ff763cd9034365e8e9882913cbd', 'platform': 'macOS-13.2.1-arm64-arm-64bit', 'max_K': 1048576}
# 2023-03-17 16:19:59,463 - confirm.adagrid.backend - DEBUG
# init took 1.635 seconds
# Output()
# ✓ Initialized. View app at https://modal.com/apps/ap-NTZF5llCf7suRyisiKGk32
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ✓ Created objects.
# ├── 🔨 Created ModalWorker.process_tiles.
# ├── 🔨 Created mount /Users/tbent/confirm/confirmasaurus/confirm
# ├── 🔨 Created mount /Users/tbent/confirm/confirmasaurus/imprint/imprint
# ├── 🔨 Created mount /Users/tbent/confirm/confirmasaurus/confirm
# ├── 🔨 Created mount /Users/tbent/confirm/confirmasaurus/imprint/imprint
# └── 🔨 Created mount .
# Output()
# 2023-03-17 16:20:02,312 - confirm.adagrid.backend - DEBUG
# setup took 2.848 seconds
# 2023-03-17 16:20:02,312 - confirm.adagrid.step - DEBUG
# waiting for work: (zone_id=0, step_id=0, packet_id=0)
# 2023-03-17 16:20:02,316 - confirm.adagrid.step - DEBUG
# waiting for work: (zone_id=1, step_id=0, packet_id=0)
# 2023-03-17 16:20:02,319 - confirm.adagrid.step - DEBUG
# waiting for work: (zone_id=2, step_id=0, packet_id=0)
# 2023-03-17 16:20:02,321 - confirm.adagrid.step - DEBUG
# waiting for work: (zone_id=3, step_id=0, packet_id=0)
# 2023-03-17 16:20:02,324 - confirm.adagrid.step - DEBUG
# Processing 2264 tiles.
# 2023-03-17 16:20:02,325 - confirm.adagrid.step - DEBUG
# Processing 2263 tiles.
# 2023-03-17 16:20:02,326 - confirm.adagrid.step - DEBUG
# Processing 2263 tiles.
# 2023-03-17 16:20:02,327 - confirm.adagrid.step - DEBUG
# Processing 2263 tiles.
# 2023-03-17 16:20:24,494 - confirm.adagrid.step - DEBUG
# Processed 2263 tiles in 22.16 seconds.
# 2023-03-17 16:20:24,497 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 2263,
#  'n_total_sims': 18538496,
#  'packet_id': 0,
#  'runtime_process_tiles': '22.161288',
#  'runtime_simulating': '7.049096',
#  'runtime_total': '22.172214',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679084424.486624',
#  'worker_id': 1,
#  'zone_id': 1}
# 2023-03-17 16:20:24,719 - confirm.adagrid.step - DEBUG
# Processed 2263 tiles in 22.39 seconds.
# 2023-03-17 16:20:24,720 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 2263,
#  'n_total_sims': 18538496,
#  'packet_id': 0,
#  'runtime_process_tiles': '22.386390',
#  'runtime_simulating': '0.248396',
#  'runtime_total': '22.393775',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679084424.712677',
#  'worker_id': 1,
#  'zone_id': 2}
# 2023-03-17 16:20:24,993 - confirm.adagrid.step - DEBUG
# Processed 2263 tiles in 22.66 seconds.
# 2023-03-17 16:20:24,994 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 2263,
#  'n_total_sims': 18538496,
#  'packet_id': 0,
#  'runtime_process_tiles': '22.660953',
#  'runtime_simulating': '0.243800',
#  'runtime_total': '22.667432',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679084424.987999',
#  'worker_id': 1,
#  'zone_id': 3}
# 2023-03-17 16:20:25,861 - confirm.adagrid.step - DEBUG
# Processed 2264 tiles in 23.53 seconds.
# 2023-03-17 16:20:25,862 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 2264,
#  'n_total_sims': 18546688,
#  'packet_id': 0,
#  'runtime_process_tiles': '23.529379',
#  'runtime_simulating': '0.729395',
#  'runtime_total': '23.537931',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679084425.854081',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:20:25,863 - confirm.adagrid.backend - DEBUG
# process_initial_incompletes took 23.551 seconds
# 2023-03-17 16:20:25,864 - confirm.adagrid.backend - DEBUG
# Zone 0 running from step 1 through step 1.
# 2023-03-17 16:20:25,864 - confirm.adagrid.backend - DEBUG
# Zone 0 beginning step 1
# 2023-03-17 16:20:25,872 - confirm.adagrid.validate - INFO
# Preparing new step with 2264 parent tiles.
# 2023-03-17 16:20:25,878 - confirm.adagrid.db - DEBUG
# finish:    zone_id  step_id  packet_id                   id  active  finisher_id  \
# 0        0        0          0  4705336852603999086   False            1
# 1        0        0          0  4705336852603999102   False            1
# 2        0        0          0  4705336852603996884   False            1
# 3        0        0          0  4705336852603999268   False            1
# 4        0        0          0  4705336852603999273   False            1
#
#    refine  deepen  split
# 0      16       0  False
# 1      16       0  False
# 2      16       0  False
# 3      16       0  False
# 4      16       0  False
# 2023-03-17 16:20:25,884 - imprint.grid - DEBUG
# _gen_short_uuids(n=0, worker_id=1, t=1679084425, n_bits=18, worker_bits=18) = [, ...]:
# 2023-03-17 16:20:25,888 - imprint.grid - DEBUG
# _gen_short_uuids(n=36224, worker_id=1, t=1679084426, n_bits=18, worker_bits=18) = [4705338708029865984 4705338708029865985 4705338708029865986, ...]:
# 2023-03-17 16:20:25,892 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:20:25,900 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:20:25,916 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:20:25,933 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:20:25,990 - imprint.grid - DEBUG
# _gen_short_uuids(n=8384, worker_id=1, t=1679084427, n_bits=18, worker_bits=18) = [4705338776749342720 4705338776749342721 4705338776749342722, ...]:
# 2023-03-17 16:20:26,242 - imprint.grid - DEBUG
# _gen_short_uuids(n=19824, worker_id=1, t=1679084428, n_bits=18, worker_bits=18) = [4705338845468819456 4705338845468819457 4705338845468819458, ...]:
# 2023-03-17 16:20:26,261 - confirm.adagrid.db - DEBUG
# finish:    zone_id  step_id  packet_id                   id  active  finisher_id  \
# 0        0        1         -1  4705338708029865984   False            1
# 1        0        1         -1  4705338708029865985   False            1
# 2        0        1         -1  4705338708029865986   False            1
# 3        0        1         -1  4705338708029865987   False            1
# 4        0        1         -1  4705338708029865996   False            1
#
#    refine  deepen  split
# 0       0       0   True
# 1       0       0   True
# 2       0       0   True
# 3       0       0   True
# 4       0       0   True
# 2023-03-17 16:20:26,284 - confirm.adagrid.step - DEBUG
# For zone 0, starting step 1 with 43250 tiles to simulate.
# 2023-03-17 16:20:26,286 - confirm.adagrid.backend - DEBUG
# {'converged': False,
#  'max_tie_est': '0.000000',
#  'n_complete': 0,
#  'n_deepen': 0,
#  'n_packets': 6,
#  'n_refine': 2264,
#  'n_tiles': 2264,
#  'next_tile_K': 8192,
#  'next_tile_at_max_K': False,
#  'next_tile_grid_cost': '0.088112',
#  'next_tile_sim_cost': '0.000562',
#  'next_tile_tie_bound': '0.088674',
#  'next_tile_tie_est': '0.000000',
#  'next_tile_total_cost': '0.088674',
#  'runtime_convergence_criterion': '0.000000',
#  'runtime_total': '0.421329',
#  'status': 'NEW_STEP',
#  'step_id': 1,
#  'step_max_grid_cost': '0.088112',
#  'step_max_sim_cost': '0.000562',
#  'step_max_total_cost': '0.088674',
#  'time': '1679084426.284483',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:20:26,290 - confirm.adagrid.backend - DEBUG
# Zone 1 running from step 1 through step 1.
# 2023-03-17 16:20:26,290 - confirm.adagrid.backend - DEBUG
# Zone 1 beginning step 1
# 2023-03-17 16:20:26,297 - confirm.adagrid.validate - INFO
# Preparing new step with 2263 parent tiles.
# 2023-03-17 16:20:26,301 - confirm.adagrid.db - DEBUG
# finish:    zone_id  step_id  packet_id                   id  active  finisher_id  \
# 0        1        0          0  4705336852603999088   False            1
# 1        1        0          0  4705336852603999104   False            1
# 2        1        0          0  4705336852603996885   False            1
# 3        1        0          0  4705336852603997304   False            1
# 4        1        0          0  4705336852603999269   False            1
#
#    refine  deepen  split
# 0      16       0  False
# 1      16       0  False
# 2      16       0  False
# 3      16       0  False
# 4      16       0  False
# 2023-03-17 16:20:26,307 - imprint.grid - DEBUG
# _gen_short_uuids(n=0, worker_id=1, t=1679084429, n_bits=18, worker_bits=18) = [, ...]:
# 2023-03-17 16:20:26,310 - imprint.grid - DEBUG
# _gen_short_uuids(n=36208, worker_id=1, t=1679084430, n_bits=18, worker_bits=18) = [4705338982907772928 4705338982907772929 4705338982907772930, ...]:
# 2023-03-17 16:20:26,313 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:20:26,318 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:20:26,328 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:20:26,444 - imprint.grid - DEBUG
# _gen_short_uuids(n=8352, worker_id=1, t=1679084431, n_bits=18, worker_bits=18) = [4705339051627249664 4705339051627249665 4705339051627249666, ...]:
# 2023-03-17 16:20:26,727 - imprint.grid - DEBUG
# _gen_short_uuids(n=20012, worker_id=1, t=1679084432, n_bits=18, worker_bits=18) = [4705339120346726400 4705339120346726401 4705339120346726402, ...]:
# 2023-03-17 16:20:26,745 - confirm.adagrid.db - DEBUG
# finish:    zone_id  step_id  packet_id                   id  active  finisher_id  \
# 0        1        1         -1  4705338982907772928   False            1
# 1        1        1         -1  4705338982907772929   False            1
# 2        1        1         -1  4705338982907772930   False            1
# 3        1        1         -1  4705338982907772931   False            1
# 4        1        1         -1  4705338982907772940   False            1
#
#    refine  deepen  split
# 0       0       0   True
# 1       0       0   True
# 2       0       0   True
# 3       0       0   True
# 4       0       0   True
# 2023-03-17 16:20:26,767 - confirm.adagrid.step - DEBUG
# For zone 1, starting step 1 with 43291 tiles to simulate.
# 2023-03-17 16:20:26,769 - confirm.adagrid.backend - DEBUG
# {'converged': False,
#  'max_tie_est': '0.000000',
#  'n_complete': 0,
#  'n_deepen': 0,
#  'n_packets': 6,
#  'n_refine': 2263,
#  'n_tiles': 2263,
#  'next_tile_K': 8192,
#  'next_tile_at_max_K': False,
#  'next_tile_grid_cost': '0.088083',
#  'next_tile_sim_cost': '0.000562',
#  'next_tile_tie_bound': '0.088644',
#  'next_tile_tie_est': '0.000000',
#  'next_tile_total_cost': '0.088644',
#  'runtime_convergence_criterion': '0.000000',
#  'runtime_total': '0.477740',
#  'status': 'NEW_STEP',
#  'step_id': 1,
#  'step_max_grid_cost': '0.088083',
#  'step_max_sim_cost': '0.000562',
#  'step_max_total_cost': '0.088644',
#  'time': '1679084426.767649',
#  'worker_id': 1,
#  'zone_id': 1}
# 2023-03-17 16:20:26,772 - confirm.adagrid.backend - DEBUG
# Zone 2 running from step 1 through step 1.
# 2023-03-17 16:20:26,773 - confirm.adagrid.backend - DEBUG
# Zone 2 beginning step 1
# 2023-03-17 16:20:26,779 - confirm.adagrid.validate - INFO
# Preparing new step with 2263 parent tiles.
# 2023-03-17 16:20:26,783 - confirm.adagrid.db - DEBUG
# finish:    zone_id  step_id  packet_id                   id  active  finisher_id  \
# 0        2        0          0  4705336852603999084   False            1
# 1        2        0          0  4705336852603999089   False            1
# 2        2        0          0  4705336852603999100   False            1
# 3        2        0          0  4705336852603996882   False            1
# 4        2        0          0  4705336852603997298   False            1
#
#    refine  deepen  split
# 0      16       0  False
# 1      16       0  False
# 2      16       0  False
# 3      16       0  False
# 4      16       0  False
# 2023-03-17 16:20:26,788 - imprint.grid - DEBUG
# _gen_short_uuids(n=0, worker_id=1, t=1679084433, n_bits=18, worker_bits=18) = [, ...]:
# 2023-03-17 16:20:26,791 - imprint.grid - DEBUG
# _gen_short_uuids(n=36208, worker_id=1, t=1679084434, n_bits=18, worker_bits=18) = [4705339257785679872 4705339257785679873 4705339257785679874, ...]:
# 2023-03-17 16:20:26,795 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:20:26,800 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:20:26,818 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:20:26,839 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:20:26,914 - imprint.grid - DEBUG
# _gen_short_uuids(n=8352, worker_id=1, t=1679084435, n_bits=18, worker_bits=18) = [4705339326505156608 4705339326505156609 4705339326505156610, ...]:
# 2023-03-17 16:20:27,150 - imprint.grid - DEBUG
# _gen_short_uuids(n=19494, worker_id=1, t=1679084436, n_bits=18, worker_bits=18) = [4705339395224633344 4705339395224633345 4705339395224633346, ...]:
# 2023-03-17 16:20:27,167 - confirm.adagrid.db - DEBUG
# finish:    zone_id  step_id  packet_id                   id  active  finisher_id  \
# 0        2        1         -1  4705339257785679872   False            1
# 1        2        1         -1  4705339257785679873   False            1
# 2        2        1         -1  4705339257785679874   False            1
# 3        2        1         -1  4705339257785679875   False            1
# 4        2        1         -1  4705339257785679884   False            1
#
#    refine  deepen  split
# 0       0       0   True
# 1       0       0   True
# 2       0       0   True
# 3       0       0   True
# 4       0       0   True
# 2023-03-17 16:20:27,188 - confirm.adagrid.step - DEBUG
# For zone 2, starting step 1 with 43140 tiles to simulate.
# 2023-03-17 16:20:27,189 - confirm.adagrid.backend - DEBUG
# {'converged': False,
#  'max_tie_est': '0.000000',
#  'n_complete': 0,
#  'n_deepen': 0,
#  'n_packets': 6,
#  'n_refine': 2263,
#  'n_tiles': 2263,
#  'next_tile_K': 8192,
#  'next_tile_at_max_K': False,
#  'next_tile_grid_cost': '0.088112',
#  'next_tile_sim_cost': '0.000562',
#  'next_tile_tie_bound': '0.088674',
#  'next_tile_tie_est': '0.000000',
#  'next_tile_total_cost': '0.088674',
#  'runtime_convergence_criterion': '0.000000',
#  'runtime_total': '0.416168',
#  'status': 'NEW_STEP',
#  'step_id': 1,
#  'step_max_grid_cost': '0.088112',
#  'step_max_sim_cost': '0.000562',
#  'step_max_total_cost': '0.088674',
#  'time': '1679084427.188265',
#  'worker_id': 1,
#  'zone_id': 2}
# 2023-03-17 16:20:27,193 - confirm.adagrid.backend - DEBUG
# Zone 3 running from step 1 through step 1.
# 2023-03-17 16:20:27,193 - confirm.adagrid.backend - DEBUG
# Zone 3 beginning step 1
# 2023-03-17 16:20:27,200 - confirm.adagrid.validate - INFO
# Preparing new step with 2263 parent tiles.
# 2023-03-17 16:20:27,204 - confirm.adagrid.db - DEBUG
# finish:    zone_id  step_id  packet_id                   id  active  finisher_id  \
# 0        3        0          0  4705336852603999085   False            1
# 1        3        0          0  4705336852603999090   False            1
# 2        3        0          0  4705336852603999101   False            1
# 3        3        0          0  4705336852603996883   False            1
# 4        3        0          0  4705336852603999106   False            1
#
#    refine  deepen  split
# 0      16       0  False
# 1      16       0  False
# 2      16       0  False
# 3      16       0  False
# 4      16       0  False
# 2023-03-17 16:20:27,210 - imprint.grid - DEBUG
# _gen_short_uuids(n=0, worker_id=1, t=1679084437, n_bits=18, worker_bits=18) = [, ...]:
# 2023-03-17 16:20:27,212 - imprint.grid - DEBUG
# _gen_short_uuids(n=36208, worker_id=1, t=1679084438, n_bits=18, worker_bits=18) = [4705339532663586816 4705339532663586817 4705339532663586818, ...]:
# 2023-03-17 16:20:27,216 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:20:27,221 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:20:27,230 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:20:27,254 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:20:27,313 - imprint.grid - DEBUG
# _gen_short_uuids(n=8368, worker_id=1, t=1679084439, n_bits=18, worker_bits=18) = [4705339601383063552 4705339601383063553 4705339601383063554, ...]:
# 2023-03-17 16:20:27,593 - imprint.grid - DEBUG
# _gen_short_uuids(n=19366, worker_id=1, t=1679084440, n_bits=18, worker_bits=18) = [4705339670102540288 4705339670102540289 4705339670102540290, ...]:
# 2023-03-17 16:20:27,609 - confirm.adagrid.db - DEBUG
# finish:    zone_id  step_id  packet_id                   id  active  finisher_id  \
# 0        3        1         -1  4705339532663586816   False            1
# 1        3        1         -1  4705339532663586817   False            1
# 2        3        1         -1  4705339532663586818   False            1
# 3        3        1         -1  4705339532663586819   False            1
# 4        3        1         -1  4705339532663586828   False            1
#
#    refine  deepen  split
# 0       0       0   True
# 1       0       0   True
# 2       0       0   True
# 3       0       0   True
# 4       0       0   True
# 2023-03-17 16:20:27,632 - confirm.adagrid.step - DEBUG
# For zone 3, starting step 1 with 43153 tiles to simulate.
# 2023-03-17 16:20:27,635 - confirm.adagrid.backend - DEBUG
# {'converged': False,
#  'max_tie_est': '0.000000',
#  'n_complete': 0,
#  'n_deepen': 0,
#  'n_packets': 6,
#  'n_refine': 2263,
#  'n_tiles': 2263,
#  'next_tile_K': 8192,
#  'next_tile_at_max_K': False,
#  'next_tile_grid_cost': '0.088112',
#  'next_tile_sim_cost': '0.000562',
#  'next_tile_tie_bound': '0.088674',
#  'next_tile_tie_est': '0.000000',
#  'next_tile_total_cost': '0.088674',
#  'runtime_convergence_criterion': '0.000000',
#  'runtime_total': '0.441430',
#  'status': 'NEW_STEP',
#  'step_id': 1,
#  'step_max_grid_cost': '0.088112',
#  'step_max_sim_cost': '0.000562',
#  'step_max_total_cost': '0.088674',
#  'time': '1679084427.632174',
#  'worker_id': 1,
#  'zone_id': 3}
# 2023-03-17 16:20:27,640 - confirm.adagrid.step - DEBUG
# Processing 8192 tiles.
# 2023-03-17 16:20:27,642 - confirm.adagrid.step - DEBUG
# Processing 8192 tiles.
# 2023-03-17 16:20:27,643 - confirm.adagrid.step - DEBUG
# Processing 8192 tiles.
# 2023-03-17 16:20:27,643 - confirm.adagrid.step - DEBUG
# Processing 8192 tiles.
# 2023-03-17 16:20:27,645 - confirm.adagrid.step - DEBUG
# Processing 8192 tiles.
# 2023-03-17 16:20:27,647 - confirm.adagrid.step - DEBUG
# Processing 2290 tiles.
# 2023-03-17 16:20:27,648 - confirm.adagrid.step - DEBUG
# Processing 8192 tiles.
# 2023-03-17 16:20:27,651 - confirm.adagrid.step - DEBUG
# Processing 8192 tiles.
# 2023-03-17 16:20:27,651 - confirm.adagrid.step - DEBUG
# Processing 8192 tiles.
# 2023-03-17 16:20:27,653 - confirm.adagrid.step - DEBUG
# Processing 8192 tiles.
# 2023-03-17 16:20:27,655 - confirm.adagrid.step - DEBUG
# Processing 8192 tiles.
# 2023-03-17 16:20:27,656 - confirm.adagrid.step - DEBUG
# Processing 2331 tiles.
# 2023-03-17 16:20:27,658 - confirm.adagrid.step - DEBUG
# Processing 8192 tiles.
# 2023-03-17 16:20:27,659 - confirm.adagrid.step - DEBUG
# Processing 8192 tiles.
# 2023-03-17 16:20:27,660 - confirm.adagrid.step - DEBUG
# Processing 8192 tiles.
# 2023-03-17 16:20:27,661 - confirm.adagrid.step - DEBUG
# Processing 8192 tiles.
# 2023-03-17 16:20:27,717 - confirm.adagrid.step - DEBUG
# Processing 8192 tiles.
# 2023-03-17 16:20:27,720 - confirm.adagrid.step - DEBUG
# Processing 2180 tiles.
# 2023-03-17 16:20:27,722 - confirm.adagrid.step - DEBUG
# Processing 8192 tiles.
# 2023-03-17 16:20:27,723 - confirm.adagrid.step - DEBUG
# Processing 8192 tiles.
# 2023-03-17 16:20:27,724 - confirm.adagrid.step - DEBUG
# Processing 8192 tiles.
# 2023-03-17 16:20:27,724 - confirm.adagrid.step - DEBUG
# Processing 8192 tiles.
# 2023-03-17 16:20:27,725 - confirm.adagrid.step - DEBUG
# Processing 8192 tiles.
# 2023-03-17 16:20:27,725 - confirm.adagrid.step - DEBUG
# Processing 2193 tiles.
# 2023-03-17 16:20:29,060 - confirm.adagrid.step - DEBUG
# Processed 2331 tiles in 1.39 seconds.
# 2023-03-17 16:20:29,060 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 2331,
#  'n_total_sims': 19095552,
#  'packet_id': 5,
#  'runtime_process_tiles': '1.394542',
#  'runtime_simulating': '0.746528',
#  'runtime_total': '1.404013',
#  'status': 'WORKING',
#  'step_id': 1,
#  'time': '1679084429.051334',
#  'worker_id': 1,
#  'zone_id': 1}
# 2023-03-17 16:20:29,804 - confirm.adagrid.step - DEBUG
# Processed 2290 tiles in 2.15 seconds.
# 2023-03-17 16:20:29,804 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 2290,
#  'n_total_sims': 18759680,
#  'packet_id': 5,
#  'runtime_process_tiles': '2.151041',
#  'runtime_simulating': '0.738010',
#  'runtime_total': '2.157283',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679084429.798304',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:20:30,659 - confirm.adagrid.step - DEBUG
# Processed 2193 tiles in 2.93 seconds.
# 2023-03-17 16:20:30,659 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 2193,
#  'n_total_sims': 17965056,
#  'packet_id': 5,
#  'runtime_process_tiles': '2.927448',
#  'runtime_simulating': '0.771470',
#  'runtime_total': '2.934093',
#  'status': 'WORKING',
#  'step_id': 3,
#  'time': '1679084430.653299',
#  'worker_id': 1,
#  'zone_id': 3}
# 2023-03-17 16:20:31,488 - confirm.adagrid.step - DEBUG
# Processed 2180 tiles in 3.76 seconds.
# 2023-03-17 16:20:31,489 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 2180,
#  'n_total_sims': 17858560,
#  'packet_id': 5,
#  'runtime_process_tiles': '3.758932',
#  'runtime_simulating': '0.821159',
#  'runtime_total': '3.768276',
#  'status': 'WORKING',
#  'step_id': 2,
#  'time': '1679084431.479663',
#  'worker_id': 1,
#  'zone_id': 2}
# 2023-03-17 16:20:33,533 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 5.88 seconds.
# 2023-03-17 16:20:33,534 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 1,
#  'runtime_process_tiles': '5.881639',
#  'runtime_simulating': '1.094600',
#  'runtime_total': '5.892437',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679084433.523684',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:20:34,909 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 7.25 seconds.
# 2023-03-17 16:20:34,909 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 1,
#  'runtime_process_tiles': '7.247310',
#  'runtime_simulating': '0.853451',
#  'runtime_total': '7.258486',
#  'status': 'WORKING',
#  'step_id': 1,
#  'time': '1679084434.898744',
#  'worker_id': 1,
#  'zone_id': 1}
# 2023-03-17 16:20:36,596 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 8.94 seconds.
# 2023-03-17 16:20:36,597 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 0,
#  'runtime_process_tiles': '8.936840',
#  'runtime_simulating': '0.859987',
#  'runtime_total': '8.948956',
#  'status': 'WORKING',
#  'step_id': 1,
#  'time': '1679084436.585282',
#  'worker_id': 1,
#  'zone_id': 1}
# 2023-03-17 16:20:37,952 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 10.30 seconds.
# 2023-03-17 16:20:37,952 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 0,
#  'runtime_process_tiles': '10.301252',
#  'runtime_simulating': '0.853704',
#  'runtime_total': '10.311672',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679084437.942189',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:20:39,525 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 11.79 seconds.
# 2023-03-17 16:20:39,526 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 2,
#  'runtime_process_tiles': '11.790840',
#  'runtime_simulating': '0.855150',
#  'runtime_total': '11.801585',
#  'status': 'WORKING',
#  'step_id': 3,
#  'time': '1679084439.515377',
#  'worker_id': 1,
#  'zone_id': 3}
# 2023-03-17 16:20:41,722 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 14.05 seconds.
# 2023-03-17 16:20:41,723 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 2,
#  'runtime_process_tiles': '14.051816',
#  'runtime_simulating': '0.847424',
#  'runtime_total': '14.062999',
#  'status': 'WORKING',
#  'step_id': 2,
#  'time': '1679084441.712152',
#  'worker_id': 1,
#  'zone_id': 2}
# 2023-03-17 16:20:43,121 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 15.47 seconds.
# 2023-03-17 16:20:43,121 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 2,
#  'runtime_process_tiles': '15.466037',
#  'runtime_simulating': '0.862444',
#  'runtime_total': '15.478352',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679084443.109286',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:20:45,129 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 17.39 seconds.
# 2023-03-17 16:20:45,129 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 3,
#  'runtime_process_tiles': '17.393827',
#  'runtime_simulating': '0.941332',
#  'runtime_total': '17.404736',
#  'status': 'WORKING',
#  'step_id': 3,
#  'time': '1679084445.118761',
#  'worker_id': 1,
#  'zone_id': 3}
# 2023-03-17 16:20:46,759 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 19.09 seconds.
# 2023-03-17 16:20:46,762 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 0,
#  'runtime_process_tiles': '19.093353',
#  'runtime_simulating': '0.850947',
#  'runtime_total': '19.104157',
#  'status': 'WORKING',
#  'step_id': 2,
#  'time': '1679084446.752016',
#  'worker_id': 1,
#  'zone_id': 2}
# 2023-03-17 16:20:48,976 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 21.30 seconds.
# 2023-03-17 16:20:48,976 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 3,
#  'runtime_process_tiles': '21.302908',
#  'runtime_simulating': '0.861141',
#  'runtime_total': '21.314844',
#  'status': 'WORKING',
#  'step_id': 2,
#  'time': '1679084448.964760',
#  'worker_id': 1,
#  'zone_id': 2}
# 2023-03-17 16:20:50,424 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 22.76 seconds.
# 2023-03-17 16:20:50,425 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 1,
#  'runtime_process_tiles': '22.757231',
#  'runtime_simulating': '0.852759',
#  'runtime_total': '22.765603',
#  'status': 'WORKING',
#  'step_id': 2,
#  'time': '1679084450.416878',
#  'worker_id': 1,
#  'zone_id': 2}
# 2023-03-17 16:20:52,090 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 24.44 seconds.
# 2023-03-17 16:20:52,091 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 4,
#  'runtime_process_tiles': '24.436757',
#  'runtime_simulating': '0.862752',
#  'runtime_total': '24.445928',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679084452.081942',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:20:53,645 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 25.99 seconds.
# 2023-03-17 16:20:53,646 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 3,
#  'runtime_process_tiles': '25.991035',
#  'runtime_simulating': '0.862670',
#  'runtime_total': '26.002358',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679084453.634937',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:20:53,647 - confirm.adagrid.backend - DEBUG
# run_zone(0, 1, 2) took 27.783 seconds
# 2023-03-17 16:20:55,002 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 27.27 seconds.
# 2023-03-17 16:20:55,003 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 1,
#  'runtime_process_tiles': '27.268969',
#  'runtime_simulating': '0.855460',
#  'runtime_total': '27.279644',
#  'status': 'WORKING',
#  'step_id': 3,
#  'time': '1679084454.992747',
#  'worker_id': 1,
#  'zone_id': 3}
# 2023-03-17 16:20:56,428 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 28.76 seconds.
# 2023-03-17 16:20:56,429 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 4,
#  'runtime_process_tiles': '28.764014',
#  'runtime_simulating': '0.857161',
#  'runtime_total': '28.773792',
#  'status': 'WORKING',
#  'step_id': 1,
#  'time': '1679084456.419745',
#  'worker_id': 1,
#  'zone_id': 1}
# 2023-03-17 16:20:58,186 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 30.52 seconds.
# 2023-03-17 16:20:58,187 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 3,
#  'runtime_process_tiles': '30.521144',
#  'runtime_simulating': '0.848663',
#  'runtime_total': '30.534041',
#  'status': 'WORKING',
#  'step_id': 1,
#  'time': '1679084458.174159',
#  'worker_id': 1,
#  'zone_id': 1}
# 2023-03-17 16:21:00,247 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 32.58 seconds.
# 2023-03-17 16:21:00,247 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 2,
#  'runtime_process_tiles': '32.583178',
#  'runtime_simulating': '0.869446',
#  'runtime_total': '32.595988',
#  'status': 'WORKING',
#  'step_id': 1,
#  'time': '1679084460.235118',
#  'worker_id': 1,
#  'zone_id': 1}
# 2023-03-17 16:21:00,248 - confirm.adagrid.backend - DEBUG
# run_zone(1, 1, 2) took 33.959 seconds
# 2023-03-17 16:21:01,821 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 34.09 seconds.
# 2023-03-17 16:21:01,824 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 0,
#  'runtime_process_tiles': '34.089759',
#  'runtime_simulating': '0.892357',
#  'runtime_total': '34.101980',
#  'status': 'WORKING',
#  'step_id': 3,
#  'time': '1679084461.811775',
#  'worker_id': 1,
#  'zone_id': 3}
# 2023-03-17 16:21:03,946 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 36.21 seconds.
# 2023-03-17 16:21:03,947 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 4,
#  'runtime_process_tiles': '36.210209',
#  'runtime_simulating': '0.880929',
#  'runtime_total': '36.222114',
#  'status': 'WORKING',
#  'step_id': 3,
#  'time': '1679084463.935586',
#  'worker_id': 1,
#  'zone_id': 3}
# 2023-03-17 16:21:03,948 - confirm.adagrid.backend - DEBUG
# run_zone(3, 1, 2) took 36.755 seconds
# 2023-03-17 16:21:05,463 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 37.74 seconds.
# 2023-03-17 16:21:05,464 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 4,
#  'runtime_process_tiles': '37.735751',
#  'runtime_simulating': '0.881661',
#  'runtime_total': '37.746527',
#  'status': 'WORKING',
#  'step_id': 2,
#  'time': '1679084465.453405',
#  'worker_id': 1,
#  'zone_id': 2}
# 2023-03-17 16:21:05,465 - confirm.adagrid.backend - DEBUG
# run_zone(2, 1, 2) took 38.692 seconds
# 2023-03-17 16:21:05,466 - confirm.adagrid.backend - DEBUG
# run_zones took 39.603 seconds
# 2023-03-17 16:21:05,611 - confirm.adagrid.backend - DEBUG
# {'converged': False,
#  'max_tie_est': '0.000000',
#  'n_tiles': 172834,
#  'n_zones': 4,
#  'next_tile_K': 8192,
#  'next_tile_at_max_K': False,
#  'next_tile_grid_cost': '0.009428',
#  'next_tile_sim_cost': '0.000562',
#  'next_tile_tie_bound': '0.009990',
#  'next_tile_tie_est': '0.000000',
#  'next_tile_total_cost': '0.009990',
#  'runtime_total': '0.144567',
#  'status': 'COORDINATED',
#  'step_id': 2,
#  'time': '1679084465.610709',
#  'worker_id': 1}
# 2023-03-17 16:21:05,612 - confirm.adagrid.backend - DEBUG
# coordinate took 0.146 seconds
# 2023-03-17 16:21:05,612 - confirm.adagrid.backend - DEBUG
# Zone 0 running from step 2 through step 3.
# 2023-03-17 16:21:05,613 - confirm.adagrid.backend - DEBUG
# Zone 0 beginning step 2
# 2023-03-17 16:21:05,652 - confirm.adagrid.validate - INFO
# Preparing new step with 43209 parent tiles.
# 2023-03-17 16:21:05,658 - confirm.adagrid.db - DEBUG
# finish:    zone_id  step_id  packet_id                   id  active  finisher_id  \
# 0        0        1          4  4705339395224647756   False            1
# 1        0        1          4  4705338845468834093   False            1
# 2        0        1          4  4705339120346741217   False            1
# 3        0        1          4  4705339670102554610   False            1
# 4        0        1          4  4705338845468834118   False            1
#
#    refine  deepen  split
# 0      16       0  False
# 1      16       0  False
# 2      16       0  False
# 3      16       0  False
# 4      16       0  False
# 2023-03-17 16:21:05,674 - imprint.grid - DEBUG
# _gen_short_uuids(n=0, worker_id=1, t=1679084465, n_bits=18, worker_bits=18) = [, ...]:
# 2023-03-17 16:21:05,695 - imprint.grid - DEBUG
# _gen_short_uuids(n=262143, worker_id=1, t=1679084466, n_bits=18, worker_bits=18) = [4705341456808935424 4705341456808935425 4705341456808935426, ...]:
# 2023-03-17 16:21:05,696 - imprint.grid - DEBUG
# _gen_short_uuids(n=262143, worker_id=1, t=1679084467, n_bits=18, worker_bits=18) = [4705341525528412160 4705341525528412161 4705341525528412162, ...]:
# 2023-03-17 16:21:05,697 - imprint.grid - DEBUG
# _gen_short_uuids(n=167058, worker_id=1, t=1679084468, n_bits=18, worker_bits=18) = [4705341594247888896 4705341594247888897 4705341594247888898, ...]:
# 2023-03-17 16:21:05,736 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:21:05,855 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:21:06,058 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:21:06,131 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:21:06,871 - imprint.grid - DEBUG
# _gen_short_uuids(n=136176, worker_id=1, t=1679084469, n_bits=18, worker_bits=18) = [4705341662967365632 4705341662967365633 4705341662967365634, ...]:
# 2023-03-17 16:21:07,515 - imprint.grid - DEBUG
# _gen_short_uuids(n=262143, worker_id=1, t=1679084470, n_bits=18, worker_bits=18) = [4705341731686842368 4705341731686842369 4705341731686842370, ...]:
# 2023-03-17 16:21:07,516 - imprint.grid - DEBUG
# _gen_short_uuids(n=25237, worker_id=1, t=1679084471, n_bits=18, worker_bits=18) = [4705341800406319104 4705341800406319105 4705341800406319106, ...]:
# 2023-03-17 16:21:07,641 - confirm.adagrid.db - DEBUG
# finish:    zone_id  step_id  packet_id                   id  active  finisher_id  \
# 0        0        2         -1  4705341456808935424   False            1
# 1        0        2         -1  4705341456808935425   False            1
# 2        0        2         -1  4705341456808935426   False            1
# 3        0        2         -1  4705341456808935427   False            1
# 4        0        2         -1  4705341456808935436   False            1
#
#    refine  deepen  split
# 0       0       0   True
# 1       0       0   True
# 2       0       0   True
# 3       0       0   True
# 4       0       0   True
# 2023-03-17 16:21:07,728 - confirm.adagrid.step - DEBUG
# For zone 0, starting step 2 with 819852 tiles to simulate.
# 2023-03-17 16:21:07,735 - confirm.adagrid.backend - DEBUG
# {'converged': False,
#  'max_tie_est': '0.000000',
#  'n_complete': 0,
#  'n_deepen': 0,
#  'n_packets': 101,
#  'n_refine': 43209,
#  'n_tiles': 43209,
#  'next_tile_K': 8192,
#  'next_tile_at_max_K': False,
#  'next_tile_grid_cost': '0.009428',
#  'next_tile_sim_cost': '0.000562',
#  'next_tile_tie_bound': '0.009990',
#  'next_tile_tie_est': '0.000000',
#  'next_tile_total_cost': '0.009990',
#  'runtime_convergence_criterion': '0.000000',
#  'runtime_total': '2.122329',
#  'status': 'NEW_STEP',
#  'step_id': 2,
#  'step_max_grid_cost': '0.009428',
#  'step_max_sim_cost': '0.000562',
#  'step_max_total_cost': '0.009990',
#  'time': '1679084467.728356',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:21:07,791 - confirm.adagrid.backend - DEBUG
# Zone 1 running from step 2 through step 3.
# 2023-03-17 16:21:07,792 - confirm.adagrid.backend - DEBUG
# Zone 1 beginning step 2
# 2023-03-17 16:21:07,830 - confirm.adagrid.validate - INFO
# Preparing new step with 43209 parent tiles.
# 2023-03-17 16:21:07,835 - confirm.adagrid.db - DEBUG
# finish:    zone_id  step_id  packet_id                   id  active  finisher_id  \
# 0        1        1          4  4705338845468834094   False            1
# 1        1        1          4  4705339670102554586   False            1
# 2        1        1          4  4705339120346741218   False            1
# 3        1        1          4  4705339670102554611   False            1
# 4        1        1          4  4705339395224647778   False            1
#
#    refine  deepen  split
# 0      16       0  False
# 1      16       0  False
# 2      16       0  False
# 3      16       0  False
# 4      16       0  False
# 2023-03-17 16:21:07,854 - imprint.grid - DEBUG
# _gen_short_uuids(n=0, worker_id=1, t=1679084472, n_bits=18, worker_bits=18) = [, ...]:
# 2023-03-17 16:21:07,873 - imprint.grid - DEBUG
# _gen_short_uuids(n=262143, worker_id=1, t=1679084473, n_bits=18, worker_bits=18) = [4705341937845272576 4705341937845272577 4705341937845272578, ...]:
# 2023-03-17 16:21:07,874 - imprint.grid - DEBUG
# _gen_short_uuids(n=262143, worker_id=1, t=1679084474, n_bits=18, worker_bits=18) = [4705342006564749312 4705342006564749313 4705342006564749314, ...]:
# 2023-03-17 16:21:07,874 - imprint.grid - DEBUG
# _gen_short_uuids(n=167058, worker_id=1, t=1679084475, n_bits=18, worker_bits=18) = [4705342075284226048 4705342075284226049 4705342075284226050, ...]:
# 2023-03-17 16:21:07,912 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:21:08,008 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:21:08,189 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:21:08,302 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:21:09,029 - imprint.grid - DEBUG
# _gen_short_uuids(n=136144, worker_id=1, t=1679084476, n_bits=18, worker_bits=18) = [4705342144003702784 4705342144003702785 4705342144003702786, ...]:
# 2023-03-17 16:21:09,631 - imprint.grid - DEBUG
# _gen_short_uuids(n=262143, worker_id=1, t=1679084477, n_bits=18, worker_bits=18) = [4705342212723179520 4705342212723179521 4705342212723179522, ...]:
# 2023-03-17 16:21:09,632 - imprint.grid - DEBUG
# _gen_short_uuids(n=24969, worker_id=1, t=1679084478, n_bits=18, worker_bits=18) = [4705342281442656256 4705342281442656257 4705342281442656258, ...]:
# 2023-03-17 16:21:09,748 - confirm.adagrid.db - DEBUG
# finish:    zone_id  step_id  packet_id                   id  active  finisher_id  \
# 0        1        2         -1  4705341937845272576   False            1
# 1        1        2         -1  4705341937845272577   False            1
# 2        1        2         -1  4705341937845272578   False            1
# 3        1        2         -1  4705341937845272579   False            1
# 4        1        2         -1  4705341937845272588   False            1
#
#    refine  deepen  split
# 0       0       0   True
# 1       0       0   True
# 2       0       0   True
# 3       0       0   True
# 4       0       0   True
# 2023-03-17 16:21:09,840 - confirm.adagrid.step - DEBUG
# For zone 1, starting step 2 with 820021 tiles to simulate.
# 2023-03-17 16:21:09,847 - confirm.adagrid.backend - DEBUG
# {'converged': False,
#  'max_tie_est': '0.000000',
#  'n_complete': 0,
#  'n_deepen': 0,
#  'n_packets': 101,
#  'n_refine': 43209,
#  'n_tiles': 43209,
#  'next_tile_K': 8192,
#  'next_tile_at_max_K': False,
#  'next_tile_grid_cost': '0.009428',
#  'next_tile_sim_cost': '0.000562',
#  'next_tile_tie_bound': '0.009990',
#  'next_tile_tie_est': '0.000000',
#  'next_tile_total_cost': '0.009990',
#  'runtime_convergence_criterion': '0.000000',
#  'runtime_total': '2.054611',
#  'status': 'NEW_STEP',
#  'step_id': 2,
#  'step_max_grid_cost': '0.009428',
#  'step_max_sim_cost': '0.000562',
#  'step_max_total_cost': '0.009990',
#  'time': '1679084469.840333',
#  'worker_id': 1,
#  'zone_id': 1}
# 2023-03-17 16:21:09,904 - confirm.adagrid.backend - DEBUG
# Zone 2 running from step 2 through step 3.
# 2023-03-17 16:21:09,905 - confirm.adagrid.backend - DEBUG
# Zone 2 beginning step 2
# 2023-03-17 16:21:09,945 - confirm.adagrid.validate - INFO
# Preparing new step with 43208 parent tiles.
# 2023-03-17 16:21:09,951 - confirm.adagrid.db - DEBUG
# finish:    zone_id  step_id  packet_id                   id  active  finisher_id  \
# 0        2        1          4  4705339670102554587   False            1
# 1        2        1          4  4705339395224647754   False            1
# 2        2        1          4  4705339670102554612   False            1
# 3        2        1          4  4705339395224647779   False            1
# 4        2        1          4  4705339670102554636   False            1
#
#    refine  deepen  split
# 0      16       0  False
# 1      16       0  False
# 2      16       0  False
# 3      16       0  False
# 4      16       0  False
# 2023-03-17 16:21:09,973 - imprint.grid - DEBUG
# _gen_short_uuids(n=0, worker_id=1, t=1679084479, n_bits=18, worker_bits=18) = [, ...]:
# 2023-03-17 16:21:09,994 - imprint.grid - DEBUG
# _gen_short_uuids(n=262143, worker_id=1, t=1679084480, n_bits=18, worker_bits=18) = [4705342418881609728 4705342418881609729 4705342418881609730, ...]:
# 2023-03-17 16:21:09,995 - imprint.grid - DEBUG
# _gen_short_uuids(n=262143, worker_id=1, t=1679084481, n_bits=18, worker_bits=18) = [4705342487601086464 4705342487601086465 4705342487601086466, ...]:
# 2023-03-17 16:21:09,996 - imprint.grid - DEBUG
# _gen_short_uuids(n=167042, worker_id=1, t=1679084482, n_bits=18, worker_bits=18) = [4705342556320563200 4705342556320563201 4705342556320563202, ...]:
# 2023-03-17 16:21:10,033 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:21:10,140 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:21:10,331 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:21:10,396 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:21:11,151 - imprint.grid - DEBUG
# _gen_short_uuids(n=136176, worker_id=1, t=1679084483, n_bits=18, worker_bits=18) = [4705342625040039936 4705342625040039937 4705342625040039938, ...]:
# 2023-03-17 16:21:11,679 - imprint.grid - DEBUG
# _gen_short_uuids(n=262143, worker_id=1, t=1679084484, n_bits=18, worker_bits=18) = [4705342693759516672 4705342693759516673 4705342693759516674, ...]:
# 2023-03-17 16:21:11,795 - confirm.adagrid.db - DEBUG
# finish:    zone_id  step_id  packet_id                   id  active  finisher_id  \
# 0        2        2         -1  4705342418881609728   False            1
# 1        2        2         -1  4705342418881609729   False            1
# 2        2        2         -1  4705342418881609730   False            1
# 3        2        2         -1  4705342418881609731   False            1
# 4        2        2         -1  4705342418881609740   False            1
#
#    refine  deepen  split
# 0       0       0   True
# 1       0       0   True
# 2       0       0   True
# 3       0       0   True
# 4       0       0   True
# 2023-03-17 16:21:11,884 - confirm.adagrid.step - DEBUG
# For zone 2, starting step 2 with 819656 tiles to simulate.
# 2023-03-17 16:21:11,892 - confirm.adagrid.backend - DEBUG
# {'converged': False,
#  'max_tie_est': '0.000000',
#  'n_complete': 0,
#  'n_deepen': 0,
#  'n_packets': 101,
#  'n_refine': 43208,
#  'n_tiles': 43208,
#  'next_tile_K': 8192,
#  'next_tile_at_max_K': False,
#  'next_tile_grid_cost': '0.009428',
#  'next_tile_sim_cost': '0.000562',
#  'next_tile_tie_bound': '0.009990',
#  'next_tile_tie_est': '0.000000',
#  'next_tile_total_cost': '0.009990',
#  'runtime_convergence_criterion': '0.000000',
#  'runtime_total': '1.986828',
#  'status': 'NEW_STEP',
#  'step_id': 2,
#  'step_max_grid_cost': '0.009428',
#  'step_max_sim_cost': '0.000562',
#  'step_max_total_cost': '0.009990',
#  'time': '1679084471.884880',
#  'worker_id': 1,
#  'zone_id': 2}
# 2023-03-17 16:21:11,949 - confirm.adagrid.backend - DEBUG
# Zone 3 running from step 2 through step 3.
# 2023-03-17 16:21:11,949 - confirm.adagrid.backend - DEBUG
# Zone 3 beginning step 2
# 2023-03-17 16:21:11,988 - confirm.adagrid.validate - INFO
# Preparing new step with 43208 parent tiles.
# 2023-03-17 16:21:11,995 - confirm.adagrid.db - DEBUG
# finish:    zone_id  step_id  packet_id                   id  active  finisher_id  \
# 0        3        1          4  4705339670102554588   False            1
# 1        3        1          4  4705339395224647755   False            1
# 2        3        1          4  4705338845468834092   False            1
# 3        3        1          4  4705339395224647780   False            1
# 4        3        1          4  4705339120346741216   False            1
#
#    refine  deepen  split
# 0      16       0  False
# 1      16       0  False
# 2      16       0  False
# 3      16       0  False
# 4      16       0  False
# 2023-03-17 16:21:12,019 - imprint.grid - DEBUG
# _gen_short_uuids(n=0, worker_id=1, t=1679084486, n_bits=18, worker_bits=18) = [, ...]:
# 2023-03-17 16:21:12,040 - imprint.grid - DEBUG
# _gen_short_uuids(n=262143, worker_id=1, t=1679084487, n_bits=18, worker_bits=18) = [4705342899917946880 4705342899917946881 4705342899917946882, ...]:
# 2023-03-17 16:21:12,041 - imprint.grid - DEBUG
# _gen_short_uuids(n=262143, worker_id=1, t=1679084488, n_bits=18, worker_bits=18) = [4705342968637423616 4705342968637423617 4705342968637423618, ...]:
# 2023-03-17 16:21:12,042 - imprint.grid - DEBUG
# _gen_short_uuids(n=167042, worker_id=1, t=1679084489, n_bits=18, worker_bits=18) = [4705343037356900352 4705343037356900353 4705343037356900354, ...]:
# 2023-03-17 16:21:12,082 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:21:12,178 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# 2023-03-17 16:21:12,369 - imprint.planar_null - DEBUG
# HyperPlane has dimension 2 but grid has dimension 4. Padding with zeros.
# ...
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 109,
#  'runtime_process_tiles': '141.476007',
#  'runtime_simulating': '0.954773',
#  'runtime_total': '141.565829',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085278.175003',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:34:39,836 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 142.84 seconds.
# 2023-03-17 16:34:39,837 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 249,
#  'runtime_process_tiles': '142.836387',
#  'runtime_simulating': '0.920265',
#  'runtime_total': '142.944356',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085279.729372',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:34:41,338 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 144.64 seconds.
# 2023-03-17 16:34:41,339 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 6,
#  'runtime_process_tiles': '144.638451',
#  'runtime_simulating': '0.921551',
#  'runtime_total': '144.730172',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085281.247575',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:34:43,952 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 147.19 seconds.
# 2023-03-17 16:34:43,953 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 66,
#  'runtime_process_tiles': '147.188108',
#  'runtime_simulating': '1.015310',
#  'runtime_total': '147.294372',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085283.846773',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:34:45,844 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 149.13 seconds.
# 2023-03-17 16:34:45,845 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 21,
#  'runtime_process_tiles': '149.127844',
#  'runtime_simulating': '1.035758',
#  'runtime_total': '149.224142',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085285.749321',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:34:46,857 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 149.99 seconds.
# 2023-03-17 16:34:46,858 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 165,
#  'runtime_process_tiles': '149.993506',
#  'runtime_simulating': '0.925786',
#  'runtime_total': '150.084821',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085286.766963',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:34:48,728 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 151.74 seconds.
# 2023-03-17 16:34:48,730 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 248,
#  'runtime_process_tiles': '151.742176',
#  'runtime_simulating': '0.983808',
#  'runtime_total': '151.838144',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085288.634792',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:34:51,811 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 155.07 seconds.
# 2023-03-17 16:34:51,811 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 55,
#  'runtime_process_tiles': '155.069356',
#  'runtime_simulating': '0.933390',
#  'runtime_total': '155.161132',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085291.719986',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:34:53,339 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 156.61 seconds.
# 2023-03-17 16:34:53,339 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 35,
#  'runtime_process_tiles': '156.610447',
#  'runtime_simulating': '0.927721',
#  'runtime_total': '156.706129',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085293.244055',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:34:56,294 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 159.60 seconds.
# 2023-03-17 16:34:56,295 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 0,
#  'runtime_process_tiles': '159.600744',
#  'runtime_simulating': '2.018598',
#  'runtime_total': '159.692090',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085296.204086',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:34:58,120 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 161.37 seconds.
# 2023-03-17 16:34:58,121 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 41,
#  'runtime_process_tiles': '161.369959',
#  'runtime_simulating': '0.952109',
#  'runtime_total': '161.481382',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085298.009808',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:34:59,783 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 162.98 seconds.
# 2023-03-17 16:34:59,784 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 92,
#  'runtime_process_tiles': '162.983222',
#  'runtime_simulating': '0.945095',
#  'runtime_total': '163.101448',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085299.666263',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:35:01,833 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 165.07 seconds.
# 2023-03-17 16:35:01,834 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 58,
#  'runtime_process_tiles': '165.070047',
#  'runtime_simulating': '0.941319',
#  'runtime_total': '165.180915',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085301.723071',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:35:03,073 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 166.25 seconds.
# 2023-03-17 16:35:03,073 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 125,
#  'runtime_process_tiles': '166.245150',
#  'runtime_simulating': '0.926997',
#  'runtime_total': '166.336509',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085302.982491',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:35:04,668 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 167.93 seconds.
# 2023-03-17 16:35:04,671 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 43,
#  'runtime_process_tiles': '167.932832',
#  'runtime_simulating': '0.953462',
#  'runtime_total': '168.029787',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085304.574273',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:35:07,246 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 170.48 seconds.
# 2023-03-17 16:35:07,246 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 76,
#  'runtime_process_tiles': '170.484070',
#  'runtime_simulating': '1.004065',
#  'runtime_total': '170.578134',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085307.152529',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:35:08,759 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 171.86 seconds.
# 2023-03-17 16:35:08,760 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 230,
#  'runtime_process_tiles': '171.856905',
#  'runtime_simulating': '0.927907',
#  'runtime_total': '171.947650',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085308.669361',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:35:10,306 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 173.60 seconds.
# 2023-03-17 16:35:10,307 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 20,
#  'runtime_process_tiles': '173.595899',
#  'runtime_simulating': '0.925707',
#  'runtime_total': '173.687378',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085310.215652',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:35:12,281 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 175.58 seconds.
# 2023-03-17 16:35:12,282 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 3,
#  'runtime_process_tiles': '175.582514',
#  'runtime_simulating': '0.927606',
#  'runtime_total': '175.676647',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085312.188208',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:35:13,896 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 177.18 seconds.
# 2023-03-17 16:35:13,897 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 17,
#  'runtime_process_tiles': '177.179933',
#  'runtime_simulating': '0.937831',
#  'runtime_total': '177.280304',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085313.797523',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:35:15,747 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 179.04 seconds.
# 2023-03-17 16:35:15,748 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 9,
#  'runtime_process_tiles': '179.035024',
#  'runtime_simulating': '0.961527',
#  'runtime_total': '179.136780',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085315.646343',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:35:17,101 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 180.40 seconds.
# 2023-03-17 16:35:17,102 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 5,
#  'runtime_process_tiles': '180.399916',
#  'runtime_simulating': '0.930634',
#  'runtime_total': '180.494367',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085317.008416',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:35:19,300 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 182.39 seconds.
# 2023-03-17 16:35:19,301 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 225,
#  'runtime_process_tiles': '182.394669',
#  'runtime_simulating': '0.962824',
#  'runtime_total': '182.491477',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085319.204301',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:35:20,918 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 184.15 seconds.
# 2023-03-17 16:35:20,919 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 83,
#  'runtime_process_tiles': '184.154595',
#  'runtime_simulating': '0.929566',
#  'runtime_total': '184.246352',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085320.828162',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:35:22,377 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 185.67 seconds.
# 2023-03-17 16:35:22,377 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 14,
#  'runtime_process_tiles': '185.665240',
#  'runtime_simulating': '0.927022',
#  'runtime_total': '185.762182',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085322.280794',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:35:44,129 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 207.23 seconds.
# 2023-03-17 16:35:44,131 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 223,
#  'runtime_process_tiles': '207.229245',
#  'runtime_simulating': '0.929219',
#  'runtime_total': '207.324048',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085344.037006',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:35:46,406 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 209.67 seconds.
# 2023-03-17 16:35:46,406 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 49,
#  'runtime_process_tiles': '209.670394',
#  'runtime_simulating': '1.054269',
#  'runtime_total': '209.759716',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085346.317216',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:35:48,491 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 211.80 seconds.
# 2023-03-17 16:35:48,491 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 7,
#  'runtime_process_tiles': '211.795195',
#  'runtime_simulating': '1.473919',
#  'runtime_total': '211.881955',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085348.404971',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:35:51,773 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 215.07 seconds.
# 2023-03-17 16:35:51,774 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 12,
#  'runtime_process_tiles': '215.067321',
#  'runtime_simulating': '1.489025',
#  'runtime_total': '215.160281',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085351.681351',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:35:54,237 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 217.34 seconds.
# 2023-03-17 16:35:54,238 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 208,
#  'runtime_process_tiles': '217.342618',
#  'runtime_simulating': '1.395057',
#  'runtime_total': '217.436909',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085354.144030',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:35:57,098 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 220.23 seconds.
# 2023-03-17 16:35:57,098 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 167,
#  'runtime_process_tiles': '220.233388',
#  'runtime_simulating': '1.604376',
#  'runtime_total': '220.324520',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085357.007857',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:36:00,454 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 223.62 seconds.
# 2023-03-17 16:36:00,456 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 123,
#  'runtime_process_tiles': '223.619404',
#  'runtime_simulating': '1.705610',
#  'runtime_total': '223.722167',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085360.353876',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:36:03,720 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 226.70 seconds.
# 2023-03-17 16:36:03,721 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 301,
#  'runtime_process_tiles': '226.701356',
#  'runtime_simulating': '1.781173',
#  'runtime_total': '226.789445',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085363.633314',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:36:06,589 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 229.87 seconds.
# 2023-03-17 16:36:06,590 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 32,
#  'runtime_process_tiles': '229.869465',
#  'runtime_simulating': '2.180242',
#  'runtime_total': '229.958466',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085366.501036',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:36:09,740 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 232.98 seconds.
# 2023-03-17 16:36:09,741 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 72,
#  'runtime_process_tiles': '232.981280',
#  'runtime_simulating': '2.076888',
#  'runtime_total': '233.075859',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085369.646972',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:36:13,959 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 237.25 seconds.
# 2023-03-17 16:36:13,960 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 13,
#  'runtime_process_tiles': '237.254835',
#  'runtime_simulating': '2.020379',
#  'runtime_total': '237.345568',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085373.869622',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:36:15,326 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 238.61 seconds.
# 2023-03-17 16:36:15,326 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 16,
#  'runtime_process_tiles': '238.612966',
#  'runtime_simulating': '1.509217',
#  'runtime_total': '238.709460',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085375.230077',
#  'worker_id': 1,
#  'zone_id': 0}
# 2023-03-17 16:36:19,128 - confirm.adagrid.step - DEBUG
# Processed 8192 tiles in 242.27 seconds.
# 2023-03-17 16:36:19,130 - confirm.adagrid.backend - DEBUG
# {'n_tiles': 8192,
#  'n_total_sims': 67108864,
#  'packet_id': 152,
#  'runtime_process_tiles': '242.273788',
#  'runtime_simulating': '2.523607',
#  'runtime_total': '242.364096',
#  'status': 'WORKING',
#  'step_id': 0,
#  'time': '1679085379.040175',
#  'worker_id': 1,
#  'zone_id': 0}

# %%
report_df = db.get_reports()
report_df['status']
# Out:
# 0         WORKING
# 1         WORKING
# 2         WORKING
# 3         WORKING
# 4        NEW_STEP
# 5        NEW_STEP
# 6        NEW_STEP
# 7        NEW_STEP
# 8         WORKING
# 9         WORKING
# 10        WORKING
# 11        WORKING
# 12    COORDINATED
# 13       NEW_STEP
# 14       NEW_STEP
# 15       NEW_STEP
# 16       NEW_STEP
# 17        WORKING
# 18       NEW_STEP
# 19        WORKING
# 20       NEW_STEP
# 21        WORKING
# 22       NEW_STEP
# 23        WORKING
# 24       NEW_STEP
# 25        WORKING
# 26        WORKING
# 27        WORKING
# 28        WORKING
# 29    COORDINATED
# 30       NEW_STEP
# 31       NEW_STEP
# 32       NEW_STEP
# 33       NEW_STEP
# 34        WORKING
# 35       NEW_STEP
# 36        WORKING
# 37       NEW_STEP
# 38        WORKING
# 39       NEW_STEP
# 40        WORKING
# 41       NEW_STEP
# 42        WORKING
# 43        WORKING
# 44        WORKING
# 45        WORKING
# 46    COORDINATED
# 47       NEW_STEP
# 48       NEW_STEP
# 49       NEW_STEP
# 50       NEW_STEP
# 51        WORKING
# 52       NEW_STEP
# 53        WORKING
# 54        WORKING
# 55       NEW_STEP
# 56       NEW_STEP
# 57        WORKING
# 58       NEW_STEP
# 59        WORKING
# 60        WORKING
# 61        WORKING
# 62        WORKING
# 63    COORDINATED
# 64       NEW_STEP
# 65       NEW_STEP
# 66       NEW_STEP
# 67       NEW_STEP
# 68        WORKING
# 69       NEW_STEP
# 70        WORKING
# 71       NEW_STEP
# 72        WORKING
# 73       NEW_STEP
# 74        WORKING
# 75       NEW_STEP
# 76        WORKING
# 77        WORKING
# 78        WORKING
# 79        WORKING
# 80    COORDINATED
# 81       NEW_STEP
# 82       NEW_STEP
# 83       NEW_STEP
# 84       NEW_STEP
# 85        WORKING
# 86       NEW_STEP
# 87        WORKING
# 88       NEW_STEP
# 89        WORKING
# 90       NEW_STEP
# 91        WORKING
# 92       NEW_STEP
# 93        WORKING
# 94        WORKING
# 95        WORKING
# 96        WORKING
# Name: status, dtype: object

# %%
# skip the first step
first_non_work = (report_df['status'] == 'WORKING').argmin()

start = report_df.iloc[first_non_work]['time']
end = report_df.iloc[-2]['time']
runtime_total = end - start
included = report_df.iloc[first_non_work:]
included_work = included[included['status'] == 'WORKING']
included_nonwork = included[included['status'] != 'WORKING']
runtime_sim = included_work['runtime_simulating'].sum()
runtime_process_tiles = included_work['runtime_process_tiles'].sum()
runtime_step_coord = included_nonwork['runtime_total'].sum()
runtime_sim, runtime_process_tiles, runtime_step_coord, runtime_total
# Out:
# (13.774923324584961, 62.66586184501648, 3.5933642387390137, 20.888691186904907)

# %%
100 * runtime_sim / runtime_total
# Out:
# 65.94440600098699
